# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'student{i}',
            'chinese':random.randint(50,100),
            'english':random.randint(50,100),
            'math':random.randint(50,100),
            'history':random.randint(50,100),
            'health':random.randint(50,100)
        }
    )

students
# Out:
# [{'name': 'student1',
#   'chinese': 83,
#   'english': 73,
#   'math': 55,
#   'history': 96,
#   'health': 74},
#  {'name': 'student2',
#   'chinese': 78,
#   'english': 92,
#   'math': 51,
#   'history': 94,
#   'health': 56},
#  {'name': 'student3',
#   'chinese': 71,
#   'english': 97,
#   'math': 68,
#   'history': 96,
#   'health': 97},
#  {'name': 'student4',
#   'chinese': 78,
#   'english': 92,
#   'math': 57,
#   'history': 71,
#   'health': 84},
#  {'name': 'student5',
#   'chinese': 82,
#   'english': 98,
#   'math': 68,
#   'history': 72,
#   'health': 67},
#  {'name': 'student6',
#   'chinese': 95,
#   'english': 58,
#   'math': 70,
#   'history': 61,
#   'health': 89},
#  {'name': 'student7',
#   'chinese': 55,
#   'english': 64,
#   'math': 77,
#   'history': 97,
#   'health': 91},
#  {'name': 'student8',
#   'chinese': 87,
#   'english': 64,
#   'math': 93,
#   'history': 78,
#   'health': 61},
#  {'name': 'student9',
#   'chinese': 94,
#   'english': 62,
#   'math': 84,
#   'history': 100,
#   'health': 98},
#  {'name': 'student10',
#   'chinese': 81,
#   'english': 55,
#   'math': 88,
#   'history': 96,
#   'health': 80},
#  {'name': 'student11',
#   'chinese': 77,
#   'english': 95,
#   'math': 50,
#   'history': 95,
#   'health': 71},
#  {'name': 'student12',
#   'chinese': 97,
#   'english': 76,
#   'math': 96,
#   'history': 86,
#   'health': 53},
#  {'name': 'student13',
#   'chinese': 64,
#   'english': 100,
#   'math': 82,
#   'history': 96,
#   'health': 99},
#  {'name': 'student14',
#   'chinese': 81,
#   'english': 96,
#   'math': 60,
#   'history': 57,
#   'health': 90},
#  {'name': 'student15',
#   'chinese': 73,
#   'english': 60,
#   'math': 83,
#   'history': 79,
#   'health': 64},
#  {'name': 'student16',
#   'chinese': 92,
#   'english': 60,
#   'math': 65,
#   'history': 81,
#   'health': 61},
#  {'name': 'student17',
#   'chinese': 56,
#   'english': 76,
#   'math': 53,
#   'history': 73,
#   'health': 83},
#  {'name': 'student18',
#   'chinese': 70,
#   'english': 70,
#   'math': 68,
#   'history': 54,
#   'health': 68},
#  {'name': 'student19',
#   'chinese': 100,
#   'english': 79,
#   'math': 84,
#   'history': 80,
#   'health': 73},
#  {'name': 'student20',
#   'chinese': 73,
#   'english': 93,
#   'math': 74,
#   'history': 94,
#   'health': 61},
#  {'name': 'student21',
#   'chinese': 61,
#   'english': 63,
#   'math': 58,
#   'history': 66,
#   'health': 69},
#  {'name': 'student22',
#   'chinese': 74,
#   'english': 55,
#   'math': 55,
#   'history': 84,
#   'health': 92},
#  {'name': 'student23',
#   'chinese': 91,
#   'english': 57,
#   'math': 84,
#   'history': 89,
#   'health': 88},
#  {'name': 'student24',
#   'chinese': 51,
#   'english': 73,
#   'math': 53,
#   'history': 73,
#   'health': 60},
#  {'name': 'student25',
#   'chinese': 81,
#   'english': 88,
#   'math': 68,
#   'history': 93,
#   'health': 98},
#  {'name': 'student26',
#   'chinese': 80,
#   'english': 94,
#   'math': 87,
#   'history': 94,
#   'health': 53},
#  {'name': 'student27',
#   'chinese': 60,
#   'english': 78,
#   'math': 91,
#   'history': 91,
#   'health': 63},
#  {'name': 'student28',
#   'chinese': 75,
#   'english': 52,
#   'math': 50,
#   'history': 58,
#   'health': 95},
#  {'name': 'student29',
#   'chinese': 66,
#   'english': 70,
#   'math': 89,
#   'history': 97,
#   'health': 93},
#  {'name': 'student30',
#   'chinese': 69,
#   'english': 79,
#   'math': 56,
#   'history': 94,
#   'health': 93},
#  {'name': 'student31',
#   'chinese': 85,
#   'english': 53,
#   'math': 100,
#   'history': 73,
#   'health': 73},
#  {'name': 'student32',
#   'chinese': 66,
#   'english': 69,
#   'math': 65,
#   'history': 82,
#   'health': 74},
#  {'name': 'student33',
#   'chinese': 60,
#   'english': 77,
#   'math': 88,
#   'history': 76,
#   'health': 95},
#  {'name': 'student34',
#   'chinese': 67,
#   'english': 62,
#   'math': 89,
#   'history': 64,
#   'health': 94},
#  {'name': 'student35',
#   'chinese': 82,
#   'english': 69,
#   'math': 61,
#   'history': 91,
#   'health': 68},
#  {'name': 'student36',
#   'chinese': 56,
#   'english': 59,
#   'math': 72,
#   'history': 76,
#   'health': 69},
#  {'name': 'student37',
#   'chinese': 70,
#   'english': 55,
#   'math': 90,
#   'history': 53,
#   'health': 68},
#  {'name': 'student38',
#   'chinese': 70,
#   'english': 91,
#   'math': 77,
#   'history': 69,
#   'health': 80},
#  {'name': 'student39',
#   'chinese': 85,
#   'english': 52,
#   'math': 60,
#   'history': 98,
#   'health': 50},
#  {'name': 'student40',
#   'chinese': 80,
#   'english': 95,
#   'math': 55,
#   'history': 63,
#   'health': 83},
#  {'name': 'student41',
#   'chinese': 91,
#   'english': 82,
#   'math': 86,
#   'history': 92,
#   'health': 82},
#  {'name': 'student42',
#   'chinese': 91,
#   'english': 80,
#   'math': 78,
#   'history': 71,
#   'health': 56},
#  {'name': 'student43',
#   'chinese': 51,
#   'english': 93,
#   'math': 72,
#   'history': 52,
#   'health': 87},
#  {'name': 'student44',
#   'chinese': 52,
#   'english': 71,
#   'math': 58,
#   'history': 74,
#   'health': 69},
#  {'name': 'student45',
#   'chinese': 61,
#   'english': 51,
#   'math': 61,
#   'history': 65,
#   'health': 57},
#  {'name': 'student46',
#   'chinese': 79,
#   'english': 65,
#   'math': 80,
#   'history': 92,
#   'health': 51},
#  {'name': 'student47',
#   'chinese': 52,
#   'english': 85,
#   'math': 100,
#   'history': 66,
#   'health': 52},
#  {'name': 'student48',
#   'chinese': 72,
#   'english': 88,
#   'math': 75,
#   'history': 100,
#   'health': 94},
#  {'name': 'student49',
#   'chinese': 66,
#   'english': 57,
#   'math': 99,
#   'history': 55,
#   'health': 92},
#  {'name': 'student50',
#   'chinese': 78,
#   'english': 70,
#   'math': 92,
#   'history': 86,
#   'health': 56}]

# %%
#參考資料 讀寫功能 https://docs.python.org/zh-tw/3/tutorial/inputoutput.html#reading-and-writing-files
file = open('student.csv', mode='w', encoding='utf-8',newline='')
file.closed
# Out:
# False
